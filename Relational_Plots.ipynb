# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
tips = sns.load_dataset('tips')
_ = sns.relplot(data=tips,x='total_bill',y='tip')

# %%
_ = sns.relplot(data=tips,x='total_bill',y='tip',hue='smoker')

# %%
_ = sns.relplot(data=tips,x='total_bill',y='tip',hue='smoker',style='smoker')

# %%
_ = sns.relplot(data=tips,x='total_bill',y='tip',hue='smoker',style='time')

# %%
_ = sns.relplot(data=tips,x='total_bill',y='tip',hue='size')

# %%
_ =sns.relplot(data=tips,x='total_bill',y='tip',hue='size',palette='ch:r=-.5,l=.75')

# %%
_ = sns.relplot(data=tips,x='total_bill',y='tip',size='size')

# %%
_ = sns.relplot(data=tips,x='total_bill',y='tip',size='size',sizes=(15,200))
